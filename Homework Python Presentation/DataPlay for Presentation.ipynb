# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
avos1_df = pd.read_csv('avos1.csv', sep='"' and ',')

# %%
avos1_df.head()
# Out:
#   Geography Timeframe Current Year Week Ending          Type  \
# 0    Albany    Weekly      2023-01-29 00:00:00  Conventional
# 1    Albany    Weekly      2023-01-22 00:00:00  Conventional
# 2    Albany    Weekly      2023-01-15 00:00:00  Conventional
# 3    Albany    Weekly      2023-01-09 00:00:00  Conventional
# 4   Atlanta    Weekly      2023-01-29 00:00:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0          1.061986                  118903.56    20652.13    69264.38
# 1          1.087200                  145606.29    31914.51    85603.85
# 2          1.064087                  124806.13    22887.57    71058.74
# 3          1.096477                  123185.36    22058.54    76314.33
# 4          0.913555                  870655.04   357694.86    23480.73
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0       20.83           21055.11              NaN              NaN
# ...

# %%
avos2022_df = pd.read_csv('avos2022.csv', sep=',')

# %%
avos2022_df.head()
# Out:
#     Week Ending  Year  Status  Total Volume  California   Chile    Mexico  \
# 0   Jan 9, 2022  2022  Actual      25242893       42476       0  24826202
# 1  Jan 16, 2022  2022  Actual      25842385      254741   45359  25417092
# 2  Jan 23, 2022  2022  Actual      27651102     1358681       0  26249028
# 3  Jan 30, 2022  2022  Actual      27067867     2351814  199580  24429687
# 4   Feb 6, 2022  2022  Actual      23700493     2529702  226796  20705339
#
#    Peru  Colombia  Dominican Republic
# 0     0    154221            219992.0
# 1     0     45359             79832.0
# 2     0     43391                 NaN
# 3     0     86783                 NaN
# 4     0    238655                 NaN

# %%
import Basemap
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import Basemap
#       2 import xarray as xr
#
# ModuleNotFoundError: No module named 'Basemap'

# %%
import pycountry

# %%
pip install pycountry

# %%
import pycountry

# %%
# generate country code  based on country name 
import pycountry 
def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
           # .alpha_3 means 3-letter country code 
           # .alpha_2 means 2-letter country code
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
avos2022_df['CODE']=alpha3code(avos2022_df.)
avos2022_df.head()

#this won't work because the column headers are country names
# Out:
#   Cell In[21], line 15
#     avos2022_df['CODE']=alpha3code(avos2022_df.)
#                                                ^
# SyntaxError: invalid syntax

# %%
#Create a mapping from country names (column headers) to ISO codes
country_name_to_iso = {}
for country in pycountry.countries:
    country_name_to_iso[country.name] = country.alpha_3

# Rename the columns (country names) with their corresponding ISO codes
avos2022_df.columns = avos2022_df.columns.map(lambda x: country_name_to_iso.get(x, x))

# this will replace the column header names with country code

# %%
avos2022_df.head()
# Out:
#     Week Ending  Year  Status  Total Volume  California     CHL       MEX  \
# 0   Jan 9, 2022  2022  Actual      25242893       42476       0  24826202
# 1  Jan 16, 2022  2022  Actual      25842385      254741   45359  25417092
# 2  Jan 23, 2022  2022  Actual      27651102     1358681       0  26249028
# 3  Jan 30, 2022  2022  Actual      27067867     2351814  199580  24429687
# 4   Feb 6, 2022  2022  Actual      23700493     2529702  226796  20705339
#
#    PER     COL       DOM
# 0    0  154221  219992.0
# 1    0   45359   79832.0
# 2    0   43391       NaN
# 3    0   86783       NaN
# 4    0  238655       NaN

# %%
import geopandas as gpd

# Load the geospatial dataset
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge your data with the geospatial dataset based on ISO codes
merged_data = world.merge(data, left_on='iso_a2', right_on='ISO_Code', how='left')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_8136\1663484376.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       4 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       6 # Merge your data with the geospatial dataset based on ISO codes
# ----> 7 merged_data = world.merge(data, left_on='iso_a2', right_on='ISO_Code', how='left')
#
# NameError: name 'data' is not defined

# %%
pip install geopandas

# %%
import geopandas as pd

# %%
import geopandas as gpd

# Load the geospatial dataset
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge your data with the geospatial dataset based on ISO codes
merged_data = world.merge(avos2022_df, left_on='iso_a2', right_on='ISO_Code', how='left')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_8136\2102629254.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 7
#       4 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       6 # Merge your data with the geospatial dataset based on ISO codes
# ----> 7 merged_data = world.merge(avos2022_df, left_on='iso_a2', right_on='ISO_Code', how='left')
#
# File ~\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1574, in GeoDataFrame.merge(self, *args, **kwargs)
#    1556 def merge(self, *args, **kwargs):
# ...

# %%
#might need to transpose the data frame because of the column headers being country codes, the rows need to be instead

# %%
avos2022_df.head()
# Out:
#     Week Ending  Year  Status  Total Volume  California     CHL       MEX  \
# 0   Jan 9, 2022  2022  Actual      25242893       42476       0  24826202
# 1  Jan 16, 2022  2022  Actual      25842385      254741   45359  25417092
# 2  Jan 23, 2022  2022  Actual      27651102     1358681       0  26249028
# 3  Jan 30, 2022  2022  Actual      27067867     2351814  199580  24429687
# 4   Feb 6, 2022  2022  Actual      23700493     2529702  226796  20705339
#
#    PER     COL       DOM
# 0    0  154221  219992.0
# 1    0   45359   79832.0
# 2    0   43391       NaN
# 3    0   86783       NaN
# 4    0  238655       NaN

# %%
avos2022_t_df = avos2022_df.transpose()

# %%
avos2022_t_df.head(10)
# Out:
#                        0             1             2             3   \
# Week Ending   Jan 9, 2022  Jan 16, 2022  Jan 23, 2022  Jan 30, 2022
# Year                 2022          2022          2022          2022
# Status             Actual        Actual        Actual        Actual
# Total Volume     25242893      25842385      27651102      27067867
# California          42476        254741       1358681       2351814
# CHL                     0         45359             0        199580
# MEX              24826202      25417092      26249028      24429687
# PER                     0             0             0             0
# COL                154221         45359         43391         86783
# DOM              219992.0       79832.0           NaN           NaN
#
#                        4             5             6             7   \
# Week Ending   Feb 6, 2022  Feb 13, 2022  Feb 20, 2022  Feb 27, 2022
# Year                 2022          2022          2022          2022
# ...

# %%
import geopandas as gpd

# Load the geospatial dataset
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge your data with the geospatial dataset based on ISO codes
merged_data = world.merge(avos2022_t_df, left_on='iso_a2', right_on='CHL', how='left')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_8136\1922638977.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 7
#       4 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       6 # Merge your data with the geospatial dataset based on ISO codes
# ----> 7 merged_data = world.merge(avos2022_t_df, left_on='iso_a2', right_on='CHL', how='left')
#
# File ~\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1574, in GeoDataFrame.merge(self, *args, **kwargs)
#    1556 def merge(self, *args, **kwargs):
# ...

# %%
#had a realisation I should trim the datset down to only what is needed for the map.
# This would be the lcoation and the total volume
# Next steps: calc total vol. per location
# make a new df

# %%
total_cal = avos2022_df['California'].sum() #testing for one column

# %%
print(total_cal)
# Out:
# 120693353

# %%
total_chl = avos2022_df['CHL'].sum()
total_mex = avos2022_df['MEX'].sum()
total_per = avos2022_df['PER'].sum()
total_col = avos2022_df['COL'].sum()
total_dom = avos2022_df['DOM'].sum()

# %%
print(total_chl, total_mex, total_per, total_col, total_dom)
# Out:
# 7095134 943190165 125458538 16690129 1011575.0

# %%
avos_totals_df = pd.DataFrame(columns=['Country Code', 'Total Volume 2022'])
data = [
    ['USA','total_cal'
    'CHL', 'total_chl']
]

# %%
avos_totals_df.head()
# Out:
# Empty DataFrame
# Columns: [Country Code, Total Volume 2022]
# Index: []

# %%
avo_dict = {
    'Country Code': ['USA','CHL','MEX', 'PER','COL','DOM'],
    'Total Vol 2022 (kg)': [120693353, 7095134, 943190165 ,125458538, 16690129, 1011575]
}

avo_totals_df = pd.DataFrame(avo_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       1 avo_dict = {
#       2     'Country Code': ['USA','CHL','MEX', 'PER','COL','DOM'],
#       3     'Total Vol 2022 (kg)': [120693353, 7095134, 943190165 ,125458538, 16690129, 1011575]
#       4 }
# ----> 6 avo_totals_df = pd.DataFrame(avo_dict)
#
# AttributeError: module 'geopandas' has no attribute 'DataFrame'

# %%
import pandas as pd
data = {'Country Code': ['USA', 'CHL', 'MEX', 'PER', 'COL', 'DOM'], 'Total Vol 2022 kg': [120693353, 7095134, 943190165, 125458538, 16690129,1011575]}
avo_totals_df=pd.DataFrame.from_dict(data)

# %%
avo_totals_df.head
# Out:
# <bound method NDFrame.head of   Country Code  Total Vol 2022 kg
# 0          USA          120693353
# 1          CHL            7095134
# 2          MEX          943190165
# 3          PER          125458538
# 4          COL           16690129
# 5          DOM            1011575>

# %%
import geopandas as gpd

# Load the geospatial dataset
world = gpd.read_file(gpd.datasets.ne_110m_admin_0_countries.dbf)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 import geopandas as gpd
#       3 # Load the geospatial dataset
# ----> 4 world = gpd.read_file(gpd.datasets.ne_110m_admin_0_countries.dbf)
#
# AttributeError: module 'geopandas.datasets' has no attribute 'ne_110m_admin_0_countries'

# %%
# Assuming 'Country_Code' is the name of the column containing country codes in your transposed DataFrame
merged_data = world.merge(avo_totals_df, left_on='iso_a2', right_on='Country Code', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Assuming 'Country_Code' is the name of the column containing country codes in your transposed DataFrame
# ----> 2 merged_data = world.merge(avo_totals_df, left_on='iso_a2', right_on='Country Code', how='left')
#
# File ~\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1574, in GeoDataFrame.merge(self, *args, **kwargs)
#    1556 def merge(self, *args, **kwargs):
#    1557     r"""Merge two ``GeoDataFrame`` objects with a database-style join.
#    1558
#    1559     Returns a ``GeoDataFrame`` if a geometry column is present; otherwise,
#    (...)
#    1572     for more details.
#    1573     """
# -> 1574     result = DataFrame.merge(self, *args, **kwargs)
#    1575     geo_col = self._geometry_column_name
#    1576     if isinstance(result, DataFrame) and geo_col in result:
#
# ...
